# %%
from ipynb.fs.defs.Pocket_Cube_Visualizer import cube_visualizer,cube

# %%
# %matplotlib notebook

# %%
cube_visualizer.default_cube()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %% [markdown]
# Just some check that the thing works

# %%
c=cube()
c.U()
c.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %%
c=cube()
c.U(),c.U(),c.U()
c.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %%
c=cube()
c.L()
c.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %%
c=cube()
c.L(),c.L(),c.L()
c.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %%
c=cube()
c.F()
c.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %%
c=cube()
c.F(),c.F(),c.F()
c.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %%
c=cube()
c.R()
c.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %%
c=cube()
c.B()
c.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %%
c=cube()
c.D()
c.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %%
c=cube()
c.scramble()
c.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %%
c2=cube(c)
c2.U()
c2.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %%
c2=cube(c)
c2.L()
c2.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %%
c2=cube(c)
c2.F()
c2.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %%
c2=cube(c)
c2.R()
c2.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %%
c2=cube(c)
c2.B()
c2.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %%
c2=cube(c)
c2.D()
c2.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %%
c.plot()
# Out:
# <img src="data:image/png;base64,..." width="724.3333333333334">

# %% [markdown]
# It seems to work
